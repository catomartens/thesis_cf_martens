# %% [markdown]
# # Graph Creation
#
# This notebook enables the generation of graphs based on pre-collected OSM data. It is important that the data has already been retrieved and stored in a GeoJSON file, with each row containing a geometry of type LineString, MultiLineString, Polygon, or MultiPolygon.
#
# The required data can be obtained using the notebooks notebook_get_data.ipynb and notebook_assign_risk.ipynb.
# The resulting GeoJSON file from those steps serves as input for this notebook; you only need to specify the city name.
# Make sure you also know which distribution center corresponds to the selected city, as this must be provided as well.

# %%
from model_get_data import read_geojson
from model_create_graph import create_graph_with_nodes
from model_add_linear_infrastructures import add_linesstrings_to_graph
from model_add_polygon_infrastructures import add_grid_polygons_to_graph
from model_connect_postnl_nodes import connect_to_nearest_edge
from model_delete_edges_in_no_fly import remove_no_fly_zones_from_graph
from model_check import fill_missing_edge_heights_from_csv, diagnose_graph

import pickle

# %% [markdown]
# ### 0. Specifying the Area
# Set the city variable to indicate which area the data was collected for.
# Set the distribution variable to specify the corresponding distribution center.
# If you're unsure which distribution center belongs to the selected city, you can look it up in the file:
# model/postNL/output/postnl_distribution_cleaned.json.

# %%
city = 'alphen-waddinxveen' # use lower case
depot = ['Goes'] # use capitalized

# %% [markdown]
# ### 0. Get Data
# Uses the read_geojson function to load and prepare the data for the selected area, so that a graph can be constructed from the OSM data.

# %%
gdf, lines_gdf, polygons_gdf, post_nl_gdf, no_fly_zones_gdf = read_geojson(f'/Users/cmartens/Documents/thesis_cf_martens/3.no_fly_zones/output/data_for_graph_{city}.geojson', depot, all=True)
# Out:
# Getting separate dataframes for lines, polygons, postnl points, distribution points and no fly zones
# Looking for distribution points in ['Goes']
# Found 1 distribution points in ['Goes']
# Found 22830 lines, 9108 polygons, 82 postnl points, 1 distribution point and 7 no-fly zones

# %%
no_fly_zones_gdf
# Out:
#                                                     name  id  \
# 32346    Industriegebied met risicos op zware ongevallen NaN
# 32347  Gebied met verbod vanuit beveiligingsoverwegingen NaN
# 32348  Gebied met verbod vanuit beveiligingsoverwegingen NaN
# 32349  geografische zone van een beveiligd gebied of ... NaN
# 32350  geografische zone van een beveiligd gebied of ... NaN
# 32351                          Natura 2000 Area De Wilck NaN
# 32352    Natura 2000 Area Nieuwkoopse Plassen & De Haeck NaN
#
#                                              description    area_type  \
# 32346  OPEN cat. vluchten zijn hier verboden SPEC cat...  No-fly zone
# 32347  OPEN cat. vluchten zijn hier verboden SPEC cat...  No-fly zone
# 32348  OPEN cat. vluchten zijn hier verboden SPEC cat...  No-fly zone
# 32349  OPEN cat. vluchten zijn hier verboden SPEC cat...  No-fly zone
# 32350  OPEN cat. vluchten zijn hier verboden SPEC cat...  No-fly zone
# 32351                     Natura 2000-besluit 7 mei 2013  No-fly zone
# 32352                Natura 2000-besluit 06 januari 2014  No-fly zone
#
#           category         risk  Height                   air_type  \
# 32346     Industry  no_fly_zone     NaN            High-Risk Areas
# 32347     Security  no_fly_zone     NaN           Restricted Zones
# 32348     Security  no_fly_zone     NaN           Restricted Zones
# 32349     Security  no_fly_zone     NaN           Restricted Zones
# 32350     Security  no_fly_zone     NaN           Restricted Zones
# 32351  Environment  no_fly_zone     NaN  Protected Nature Reserves
# 32352  Environment  no_fly_zone     NaN  Protected Nature Reserves
#
#                                                 geometry
# 32346  POLYGON ((104560.374 461789.357, 104560.336 46...
# 32347  POLYGON ((103921.671 460714.176, 103921.633 46...
# 32348  POLYGON ((103752.757 460932.286, 103752.719 46...
# 32349  POLYGON ((104950.064 461596.382, 104950.052 46...
# 32350  POLYGON ((100237.286 460193.56, 100237.274 460...
# 32351  MULTIPOLYGON (((97168.115 459219.521, 97153.53...
# 32352  MULTIPOLYGON (((116918.154 464732.231, 116914....

# %% [markdown]
# ## 1. Create Initial Graph with Nodes
# Creates an unconnected graph by adding all PostNL points and the distribution center as nodes.

# %%
G = create_graph_with_nodes(post_nl_gdf)
# Out:
# Graph creation summary:
#  - Total rows: 82
#  - Distributions added: 1
#  - PostNL added: 81
#  - Skipped (non-Point geometry): 0

# %% [markdown]
# ## 2. Add LineStrings to Graph
# Adds all LineString and MultiLineString geometries to the graph as edges. Ensures they are connected to each other and to the existing nodes by snapping nearby points together.

# %%
G_with_linestrings = add_linesstrings_to_graph(G, lines_gdf)
# Out:
# Exploding MultiLineString geometries into separate LineString geometries.
# Finding intersections between lines.
# Found 82608 intersection points.
# Adding snapped points to the graph.
# /Users/cmartens/Library/Python/3.13/lib/python/site-packages/shapely/linear.py:88: RuntimeWarning: invalid value encountered in line_locate_point
#   return lib.line_locate_point(line, other)
# /Users/cmartens/Library/Python/3.13/lib/python/site-packages/shapely/linear.py:88: RuntimeWarning: invalid value encountered in line_locate_point
#   return lib.line_locate_point(line, other)
# /Users/cmartens/Library/Python/3.13/lib/python/site-packages/shapely/linear.py:88: RuntimeWarning: invalid value encountered in line_locate_point
#   return lib.line_locate_point(line, other)
# /Users/cmartens/Library/Python/3.13/lib/python/site-packages/shapely/linear.py:88: RuntimeWarning: invalid value encountered in line_locate_point
#   return lib.line_locate_point(line, other)
# /Users/cmartens/Library/Python/3.13/lib/python/site-packages/shapely/linear.py:88: RuntimeWarning: invalid value encountered in line_locate_point
#   return lib.line_locate_point(line, other)
# /Users/cmartens/Library/Python/3.13/lib/python/site-packages/shapely/linear.py:88: RuntimeWarning: invalid value encountered in line_locate_point
#   return lib.line_locate_point(line, other)
# /Users/cmartens/Library/Python/3.13/lib/python/site-packages/shapely/linear.py:88: RuntimeWarning: invalid value encountered in line_locate_point
#   return lib.line_locate_point(line, other)
# /Users/cmartens/Library/Python/3.13/lib/python/site-packages/shapely/linear.py:88: RuntimeWarning: invalid value encountered in line_locate_point
#   return lib.line_locate_point(line, other)
#  Graph update summary:
#  - Lines found: 22830
#  - Intersections found: 22629
#  - Line intersection nodes added: 25979
#  - Edges added: 89330
#  - New waypoint nodes added: 52838
#  - Skipped short/invalid segments: 2300
#  - Final graph has 79630 nodes and 89862 edges

# %% [markdown]
# ## 3. Add polygons to
#
# Generates a grid for each polygon and connects the grid points to the polygon boundaries. Adds all polygons to the graph and ensures they are properly snapped to the existing graph structure, so that all elements are correctly connected.

# %%
G_with_grids_and_boundaries = add_grid_polygons_to_graph(G_with_linestrings, polygons_gdf, lines_gdf)
# Out:
# Excecuting add_grid_polygons_to_graph function
# G before polygons: 79630 nodes, 89862 edges
#
#  Step 1
# Adding grid structure to 9108 polygons, with grid size 50 and max cells 10000.
# G after grid: 183619 nodes, 220591 edges
#
#  Step 2
# Adding local polygon boundaries to the graph with snap tolerance 35 and boundary sample distance 50.
#
#  Step 3
# Finding intersections for 424698 edges.
# Found 1005599 intersections between polygon-polygon and polygon-line.
#
#  Step 4
# Number of unique snapt points: 324821
#
#  Step 5
# Mapping geometries to edges.
#
#  Step 6
# Adding intersection nodes.
# Intersection nodes added: 60074
#
#  Step 7
#  Splitting edges at intersections.
#  Edges split and added: 0
#
#  Step 8
# STRtree indexing over 104230 polygon_boundary points.
# Connected nodes: 30803
# Skipped 47047 line intersections/waypoints that could not be connected to polygon boundaries. Consider increasing the max_connection_distance.
# G after connecting: 347923 nodes, 538079 edges

# %% [markdown]
# ## 4. Connect postnl and distribution points to graph
#
# All points are linked to the nearest location in the graph using a connector, provided the distance does not exceed max_connection_distance.

# %%
G_with_grids_and_boundaries_connected = connect_to_nearest_edge(G_with_grids_and_boundaries, max_connection_distance=10)
# Out:
# Total edges indexed: 538079
# Start iterating over postnl and distribution nodes.
# Node 0 connected to edge ((np.float64(104169.3), np.float64(450747.668))-(104180.479, 450762.63)) via new node POINT (104179.15837716208 450760.862475275) at d = 8.67 m
# Node 1 connected to edge ((103460.764, 450132.613)-(103420.234, 450133.656)) via new node POINT (103453.4920450252 450132.8001366652) at d = 3.13 m
# Node 2 connected to edge ((105262.931, 450842.367)-(105262.931, 450868.86)) via new node POINT (105262.93090006734 450862.52590566926) at d = 2.40 m
# Node 3 connected to edge ((104662.931, 449392.367)-(104612.931, 449392.357)) via new node POINT (104620.06979521007 449392.35838599905) at d = 5.26 m
# Node 4 connected to edge ((104328.235, 453174.248)-(104328.235, 453223.785)) via new node POINT (104328.23500360834 453212.0651888811) at d = 2.68 m
# Node 5 connected to edge ((102417.22, 448079.461)-(102418.2, 448056.205)) via new node POINT (102417.82633599809 448065.07373607904) at d = 2.84 m
# Node 6 connected to edge ((np.float64(100453.099), np.float64(460696.402))-(100423.049, 460677.604)) via new node POINT (100453.04728432212 460696.3696488748) at d = 8.12 m
# Node 7 connected to edge ((104359.427, 453220.833)-(104374.643, 453219.321)) via new node POINT (104363.62302627398 453220.41604470776) at d = 4.36 m
# Node 8 connected to edge ((np.float64(103455.358), np.float64(450120.797))-(103462.931, 450113.221)) via new node POINT (103457.02917123631 450119.12516673893) at d = 5.28 m
# Node 9 connected to edge ((103262.931, 449592.367)-(103262.931, 449542.428)) via new node POINT (103262.93094010052 449549.5845131704) at d = 1.28 m
# Node 10 connected to edge ((104712.931, 451442.367)-(104712.931, 451477.402)) via new node POINT (104712.93088381739 451467.66359140107) at d = 0.37 m
# Node 11 connected to edge ((103236.085, 449814.507)-(103236.06, 449823.976)) via new node POINT (103236.07307662793 449819.02309640683) at d = 1.84 m
# Node 12 connected to edge ((104050.591, 451904.912)-(104030.502, 451908.511)) via new node POINT (104031.14576096971 451908.3956684389) at d = 5.53 m
# Node 13 connected to edge ((104694.318, 452078.319)-(104692.962, 452042.367)) via new node POINT (104693.30523118208 452051.46718249115) at d = 1.52 m
# Node 14 connected to edge ((100025.767, 460076.993)-(np.float64(100024.806), np.float64(460107.124))) via new node POINT (100025.21655798049 460094.2514479607) at d = 8.16 m
# Node 15 connected to edge ((104812.931, 448792.367)-(104812.931, 448748.973)) via new node POINT (104812.93090312723 448759.0300272828) at d = 0.46 m
# Node 16 connected to edge ((105028.968, 454177.577)-(105057.66, 454170.692)) via new node POINT (105049.02391378062 454172.7644407846) at d = 2.24 m
# Node 17 connected to edge ((103217.827, 455581.424)-(103167.41, 455581.388)) via new node POINT (103177.97558095462 455581.39554866176) at d = 3.18 m
# Node 18 connected to edge ((105228.235, 455024.248)-(105228.235, 455074.248)) via new node POINT (105228.23501525163 455063.7724469984) at d = 4.23 m
# Node 80 connected to edge ((np.float64(99033.151), np.float64(460441.996))-(99122.355, 460419.695)) via new node POINT (99035.13611232663 460441.4997219183) at d = 3.64 m
# Node 166248 too far from any edge: 77236.79 m
#
#  Summary of connections:
#  - Connected: 80
#  - Skipped: 2

# %% [markdown]
# ## 5. Delete edges inside nofly zones
#
# All edges located within no-fly zones are detected and removed from the graph.

# %%
G_final = remove_no_fly_zones_from_graph(G_with_grids_and_boundaries_connected, no_fly_zones_gdf)
# Out:
# Get all lines from the graph.
# Get all lines that are inside no-fly zones.
# Checking against 7 no-fly zones.
# 11113 edges marked for removal (within no-fly zones).
# Number of edges inside no-fly zones: 11113
# Removing filtered edges from the graph.
# 11113 edges removed from the graph.

# %% [markdown]
# ## 6. Save graph
#
# Graph will be saved to output folder.

# %%
with open(f"output/{city}_raw.pkl", "wb") as f:
    pickle.dump(G_final, f)

print(f"Graph saved to output/{city}_raw.pkl")
# Out:
# Graph saved to output/alphen-waddinxveen_raw.pkl

# %% [markdown]
# ## 7. Plot graph

# %% [markdown]
# Plotting the graph on Folium.

# %%
# plot_graph_on_folium(G_final, gdf_polygons=polygons_gdf, plot_waypoints=True)

# %% [markdown]
# # 8. Check graph
#
# Use diagnose_graph to check if all nodes and edges are added correctly. If some height are missed these can still be added by using fill_missing_edge_heights_from_gdf.

# %%
diagnose_graph(G_final)
# Out:
# GRAPH DIAGNOSTICS
#
# Graph is NOT fully connected. Components: 20268
# Component size distribution: Counter({1: 18590, 4: 451, 6: 186, 2: 129, 3: 61, 8: 59, 9: 56, 10: 44, 7: 40, 5: 39, 12: 35, 11: 33, 18: 22, 15: 21, 22: 20, 21: 19, 14: 16, 32: 15, 13: 15, 17: 15, 16: 14, 27: 14, 19: 12, 26: 12, 29: 12, 33: 12, 31: 11, 24: 11, 40: 11, 41: 11, 25: 11, 35: 10, 28: 10, 37: 9, 23: 9, 44: 9, 30: 9, 20: 8, 48: 8, 38: 8, 56: 7, 47: 7, 36: 7, 49: 7, 34: 7, 66: 7, 39: 6, 53: 6, 43: 6, 45: 6, 52: 5, 54: 4, 42: 4, 74: 4, 58: 4, 64: 4, 82: 4, 70: 4, 67: 4, 51: 3, 115: 3, 63: 3, 57: 3, 46: 3, 69: 3, 145: 2, 87: 2, 116: 2, 85: 2, 114: 2, 72: 2, 81: 2, 112: 2, 122: 2, 204: 2, 61: 2, 59: 2, 100: 2, 55: 2, 88: 2, 50: 2, 91: 2, 65: 2, 299387: 1, 78: 1, 325: 1, 147: 1, 267: 1, 167: 1, 203: 1, 271: 1, 97: 1, 385: 1, 129: 1, 132: 1, 186: 1, 93: 1, 124: 1, 108: 1, 83: 1, 79: 1, 134: 1, 338: 1, 76: 1, 159: 1, 68: 1, 89: 1, 105: 1, 95: 1, 80: 1, 101: 1, 155: 1, 150: 1, 202: 1, 149: 1, 92: 1, 62: 1})
#
# Node types (ntype):
#  - postnl: 81
#  - distribution: 1
#  - line_intersection: 25979
#  - waypoint: 53649
#  - grid_point: 103989
#  - polygon_boundary: 104230
#  - poly_intersection: 60074
#
# Edge types (etype):
#  - postnl_connector: 77
#  - Regional roads: 22761
#  - Pedestrian and cycling paths: 48099
#  - Tracks and rural access roads: 25751
#  - connector: 30209
#  - Residential areas: 38986
#  - Industrial zones: 11075
#  - Cultural sites: 5089
#  - Living and residential streets: 4110
#  - Meadows and open grass: 266031
#  - Motorways and major roads: 2901
#  - Railways: 1612
#  - Rivers, canals and streams: 1993
#  - Retail zones: 1261
#  - Forests and woodlands: 29668
#  - Lakes and ponds: 166
#  - Power lines: 85
#  - Schools and universities: 1134
#  - Wetlands: 948
#  - Agricultural lands: 34049
#  - Commercial zones: 120
#  - Recreational zones: 454
#  - Hospitals: 94
#  - Religious sites: 393
#  - High infrastructures: 6
#  - Communication towers: 5
#  - Power plants: 47
#  - Prisons: 2
#
#  Missing node attributes:
#  - geometry: 0 missing
#  - ntype: 0 missing
#
# Missing edge attributes:
#  - geometry: 0 missing
#  - length: 0 missing
#  - risk: 0 missing
#  - height: 154 missing
#  - etype: 0 missing
#
# Diagnostics complete.

# %%
G_final = fill_missing_edge_heights_from_csv(G_final)
# Out:
# Height map loaded from CSV: {'Motorways and major roads': 30.0, 'Regional roads': 30.0, 'Tracks and rural access roads': 30.0, 'Living and residential streets': 30.0, 'Pedestrian and cycling paths': 30.0, 'Railways': 30.0, 'Power lines': 60.0, 'Power plants': 60.0, 'Communication towers': 60.0, 'High infrastructures': 60.0, 'Industrial zones': 60.0, 'Commercial zones': 60.0, 'Retail zones': 60.0, 'Residential areas': 60.0, 'Recreational zones': 30.0, 'Agricultural lands': 30.0, 'Forests and woodlands': 30.0, 'Meadows and open grass': 30.0, 'Rivers, canals and streams': 30.0, 'Lakes and ponds': 30.0, 'Water reservoirs': 30.0, 'Wetlands': 30.0, 'Schools and universities': 30.0, 'Hospitals': 60.0, 'Prisons': 60.0, 'Religious sites': 30.0, 'Cultural sites': 30.0, 'Cemeteries': 30.0, 'Parks': 30.0, 'connector': 30.0}
# Patched edge ((104743.957, 462726.729) → POINT (104740.18141350291 462727.1187671847)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((104708.949, 462730.343) → POINT (104740.18141350291 462727.1187671847)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((103952.542, 459246.971) → POINT (103958.59490598082 459253.7363517549)) with height=30.0 from etype='Regional roads'
# Patched edge ((103460.764, 450132.613) → POINT (103453.4920450252 450132.8001366652)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((103236.085, 449814.507) → POINT (103236.07307662793 449819.02309640683)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((100888.897, 456714.011) → POINT (100889.15136948448 456705.4165239834)) with height=60.0 from etype='Residential areas'
# Patched edge ((104753.219, 461195.16) → POINT (104771.55018553435 461194.3648178395)) with height=30.0 from etype='Regional roads'
# Patched edge ((102983.151, 461407.048) → POINT (102974.29664148296 461398.6268856552)) with height=30.0 from etype='Regional roads'
# Patched edge ((107633.698, 458773.826) → POINT (107650.44888738701 458772.0142976658)) with height=30.0 from etype='Regional roads'
# Patched edge ((104359.427, 453220.833) → POINT (104363.62302627398 453220.41604470776)) with height=30.0 from etype='Regional roads'
# Patched edge ((106289.568, 462150.443) → POINT (106282.94714265662 462152.90331242525)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((106292.326, 459109.882) → POINT (106283.78354614142 459105.7958722495)) with height=30.0 from etype='connector'
# Patched edge ((105602.48, 460512.955) → POINT (105540.28658744147 460502.3808684885)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((105862.872, 462901.45) → POINT (105869.57838491719 462904.55760077195)) with height=30.0 from etype='connector'
# Patched edge ((105372.68, 461937.373) → POINT (105372.09553756741 461932.1013469809)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((102915.928, 454606.185) → POINT (102912.3081888302 454606.59844118747)) with height=30.0 from etype='Tracks and rural access roads'
# Patched edge ((104654.365, 460790.257) → POINT (104654.06496651049 460781.81008622405)) with height=30.0 from etype='Tracks and rural access roads'
# Patched edge ((106276.589, 462155.266) → POINT (106282.94714265662 462152.90331242525)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((100295.301, 456789.968) → POINT (100307.86979590892 456789.28860562656)) with height=30.0 from etype='Regional roads'
# Patched edge ((104773.298, 461194.289) → POINT (104771.55018553435 461194.3648178395)) with height=30.0 from etype='Regional roads'
# Patched edge ((97998.573, 457573.03) → POINT (98004.65185040642 457572.76332738705)) with height=30.0 from etype='Tracks and rural access roads'
# Patched edge ((104239.122, 452131.461) → POINT (104240.31529492966 452138.755884811)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((105773.256, 460682.601) → POINT (105769.55847261695 460697.5111555685)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((104050.591, 451904.912) → POINT (104031.14576096971 451908.3956684389)) with height=30.0 from etype='Regional roads'
# Patched edge ((105752.989, 460764.327) → POINT (105769.55847261695 460697.5111555685)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((104694.318, 452078.319) → POINT (104693.30523118208 452051.46718249115)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((104471.531, 462570.268) → POINT (104467.97821928975 462534.86220225913)) with height=30.0 from etype='Regional roads'
# Patched edge ((104374.643, 453219.321) → POINT (104363.62302627398 453220.41604470776)) with height=30.0 from etype='Regional roads'
# Patched edge ((105595.31, 461758.618) → POINT (105636.81809563676 461746.66450899956)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((100326.566, 456788.278) → POINT (100307.86979590892 456789.28860562656)) with height=30.0 from etype='Regional roads'
# Patched edge ((106761.352, 462169.139) → POINT (106761.20479429248 462186.55033015937)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((104437.529, 461007.282) → POINT (104437.9346644066 461014.1186639855)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((104668.504, 463184.102) → POINT (104674.91623381441 463199.58249681746)) with height=30.0 from etype='Regional roads'
# Patched edge ((100293.727, 460339.123) → POINT (100302.51939436392 460292.9864915038)) with height=30.0 from etype='Regional roads'
# Patched edge ((104306.636, 454271.947) → POINT (104302.64997829257 454258.29758999567)) with height=30.0 from etype='Regional roads'
# Patched edge ((105647.137, 459371.09) → POINT (105659.48320753814 459363.8352430643)) with height=30.0 from etype='Regional roads'
# Patched edge ((104294.374, 454229.958) → POINT (104302.64997829257 454258.29758999567)) with height=30.0 from etype='Regional roads'
# Patched edge ((103236.06, 449823.976) → POINT (103236.07307662793 449819.02309640683)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((103420.234, 450133.656) → POINT (103453.4920450252 450132.8001366652)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((104261.9, 454546.474) → POINT (104261.43284511603 454541.7111630958)) with height=30.0 from etype='Regional roads'
# Patched edge ((105641.532, 461745.307) → POINT (105636.81809563676 461746.66450899956)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((103904.51, 453929.363) → POINT (103902.11172482838 453963.8651093199)) with height=30.0 from etype='Tracks and rural access roads'
# Patched edge ((105371.205, 461924.069) → POINT (105372.09553756741 461932.1013469809)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((104819.245, 450891.288) → POINT (104819.60781476909 450924.6523472094)) with height=30.0 from etype='Cultural sites'
# Patched edge ((np.float64(105700.584), np.float64(459339.684)) → POINT (105659.48320753814 459363.8352430643)) with height=30.0 from etype='Regional roads'
# Patched edge ((np.float64
# Patched edge ((105128.235, 454324.248) → POINT (105128.23500448753 454358.41348916705)) with height=60.0 from etype='Residential areas'
# Patched edge ((105228.235, 455024.248) → POINT (105228.23501525163 455063.7724469984)) with height=60.0 from etype='Residential areas'
# Patched edge ((105228.235, 455074.248) → POINT (105228.23501525163 455063.7724469984)) with height=60.0 from etype='Residential areas'
# Patched edge ((106478.235, 454624.248) → POINT (106473.63283226166 454624.2480254777)) with height=60.0 from etype='Residential areas'
# Patched edge ((101174.017, 460820.544) → POINT (101174.01694213985 460842.25387847144)) with height=60.0 from etype='Residential areas'
# Patched edge ((99589.611, 456689.885) → POINT (99589.61100852319 456671.9422013051)) with height=60.0 from etype='Residential areas'
# Patched edge ((100589.611, 456839.885) → POINT (100574.81087415511 456839.88512986776)) with height=60.0 from etype='Residential areas'
# Patched edge ((100889.611, 456689.885) → POINT (100889.15136948448 456705.4165239834)) with height=60.0 from etype='Residential areas'
# Patched edge ((103262.931, 449592.367) → POINT (103262.93094010052 449549.5845131704)) with height=60.0 from etype='Residential areas'
# Patched edge ((104362.931, 451392.367) → POINT (104340.94283725997 451392.36688090744)) with height=60.0 from etype='Residential areas'
# Patched edge ((104662.931, 449392.367) → POINT (104620.06979521007 449392.35838599905)) with height=60.0 from etype='Residential areas'
# Patched edge ((104712.931, 448592.367) → POINT (104734.76742380389 448595.7915257392)) with height=60.0 from etype='Residential areas'
# Patched edge ((104712.931, 451442.367) → POINT (104712.93088381739 451467.66359140107)) with height=60.0 from etype='Residential areas'
# Patched edge ((104812.931, 448792.367) → POINT (104812.93090312723 448759.0300272828)) with height=60.0 from etype='Residential areas'
# Patched edge ((105262.931, 450842.367) → POINT (105262.93090006734 450862.52590566926)) with height=60.0 from etype='Residential areas'
# Patched edge ((102417.22, 448079.461) → POINT (102417.82633599809 448065.07373607904)) with height=60.0 from etype='Industrial zones'
# Patched edge ((104583.97, 460045.897) → POINT (104585.22154616745 460056.2367062505)) with height=60.0 from etype='Retail zones'
# Patched edge ((105028.968, 454177.577) → POINT (105049.02391378062 454172.7644407846)) with height=60.0 from etype='Retail zones'
# Patched edge ((109944.367, 457649.605) → POINT (109944.36710268598 457658.13372336316)) with height=60.0 from etype='Residential areas'
# Patched edge ((105917.921, 459819.996) → POINT (105911.92200457746 459817.2797689225)) with height=60.0 from etype='Residential areas'
# Patched edge ((105402.014, 459046.087) → POINT (105380.24135677806 459060.54121034796)) with height=60.0 from etype='Residential areas'
# Patched edge ((105148.202, 451555.095) → POINT (105138.10161232443 451527.33751565084)) with height=60.0 from etype='Industrial zones'
# Patched edge ((107556.865, 458966.56) → POINT (107572.46130669415 458957.62321882806)) with height=60.0 from etype='Residential areas'
# Patched edge ((107600.26, 458941.694) → POINT (107572.46130669415 458957.62321882806)) with height=60.0 from etype='Residential areas'
# Patched edge ((105901.593, 459812.603) → POINT (105911.92200457746 459817.2797689225)) with height=60.0 from etype='Residential areas'
# Patched edge ((106281.664, 459104.782) → POINT (106283.78354614142 459105.7958722495)) with height=30.0 from etype='connector'
# Patched edge ((107308.42, 458388.798) → POINT (107302.2703370812 458379.6309380495)) with height=30.0 from etype='Meadows and open grass'
# Patched edge ((100953.187, 460815.573) → POINT (100948.95536359174 460796.54278451885)) with height=30.0 from etype='Forests and woodlands'
# Patched edge ((106706.102, 462597.03) → POINT (106692.94324963274 462576.9082869678)) with height=30.0 from etype='Meadows and open grass'
# Patched edge ((106688.958, 462570.814) → POINT (106692.94324963274 462576.9082869678)) with height=30.0 from etype='Meadows and open grass'
# Patched edge ((106271.926, 461592.016) → POINT (106274.42131009711 461601.79918762675)) with height=30.0 from etype='Meadows and open grass'
# Patched edge ((105872.299, 462905.818) → POINT (105869.57838491719 462904.55760077195)) with height=30.0 from etype='connector'
# Patched edge ((104819.624, 450926.111) → POINT (104819.60781476909 450924.6523472094)) with height=30.0 from etype='Cultural sites'
# Patched edge ((104328.235, 453223.785) → POINT (104328.23500360834 453212.0651888811)) with height=60.0 from etype='Residential areas'
# Patched edge ((104325.848, 451392.367) → POINT (104340.94283725997 451392.36688090744)) with height=60.0 from etype='Residential areas'
# Patched edge ((104466.144, 462516.583) → POINT (104467.97821928975 462534.86220225913)) with height=30.0 from etype='Regional roads'
# Patched edge ((105262.931, 450868.86) → POINT (105262.93090006734 450862.52590566926)) with height=60.0 from etype='Residential areas'
# Patched edge ((103167.41, 455581.388) → POINT (103177.97558095462 455581.39554866176)) with height=60.0 from etype='Residential areas'
# Patched edge ((106279.85, 461623.086) → POINT (106274.42131009711 461601.79918762675)) with height=30.0 from etype='Meadows and open grass'
# Patched edge ((106450.249, 454624.248) → POINT (106473.63283226166 454624.2480254777)) with height=60.0 from etype='Residential areas'
# Patched edge ((104712.931, 451477.402) → POINT (104712.93088381739 451467.66359140107)) with height=60.0 from etype='Residential areas'
# Patched edge ((103971.437, 459268.09) → POINT (103958.59490598082 459253.7363517549)) with height=30.0 from etype='Regional roads'
# Patched edge ((105367.342, 459069.105) → POINT (105380.24135677806 459060.54121034796)) with height=60.0 from etype='Residential areas'
# Patched edge ((100758.078, 460217.721) → POINT (100757.43973626789 460179.3234079961)) with height=60.0 from etype='Residential areas'
# Patched edge ((103262.931, 449542.428) → POINT (103262.93094010052 449549.5845131704)) with height=60.0 from etype='Residential areas'
# Patched edge ((102959.178, 461384.248) → POINT (102974.29664148296 461398.6268856552)) with height=30.0 from etype='Regional roads'
# Patched edge ((101574.017, 461158.925) → POINT (101555.33284983964 461154.8815121056)) with height=30.0 from etype='Regional roads'
# Patched edge ((100907.247, 460455.8) → POINT (100907.24688873481 460420.4611248647)) with height=60.0 from etype='Residential areas'
# Patched edge ((104692.962, 452042.367) → POINT (104693.30523118208 452051.46718249115)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((105526.936, 460500.111) → POINT (105540.28658744147 460502.3808684885)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((102844.791, 454614.31) → POINT (102912.3081888302 454606.59844118747)) with height=30.0 from etype='Tracks and rural access roads'
# Patched edge ((104747.886, 448597.849) → POINT (104734.76742380389 448595.7915257392)) with height=60.0 from etype='Residential areas'
# Patched edge ((104240.906, 452142.367) → POINT (104240.31529492966 452138.755884811)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((102418.2, 448056.205) → POINT (102417.82633599809 448065.07373607904)) with height=60.0 from etype='Industrial zones'
# Patched edge ((104612.931, 449392.357) → POINT (104620.06979521007 449392.35838599905)) with height=60.0 from etype='Residential areas'
# Patched edge ((104259.72, 454524.248) → POINT (104261.43284511603 454541.7111630958)) with height=30.0 from etype='Regional roads'
# Patched edge ((104445.827, 459208.071) → POINT (104440.79415341787 459209.69935767795)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((104438.461, 461022.989) → POINT (104437.9346644066 461014.1186639855)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((105128.235, 454372.657) → POINT (105128.23500448753 454358.41348916705)) with height=60.0 from etype='Residential areas'
# Patched edge ((105057.66, 454170.692) → POINT (105049.02391378062 454172.7644407846)) with height=60.0 from etype='Retail zones'
# Patched edge ((104587.737, 460077.014) → POINT (104585.22154616745 460056.2367062505)) with height=60.0 from etype='Retail zones'
# Patched edge ((100316.863, 460217.721) → POINT (100302.51939436392 460292.9864915038)) with height=30.0 from etype='Regional roads'
# Patched edge ((103901.39, 453974.248) → POINT (103902.11172482838 453963.8651093199)) with height=30.0 from etype='Tracks and rural access roads'
# Patched edge ((104812.931, 448748.973) → POINT (104812.93090312723 448759.0300272828)) with height=60.0 from etype='Residential areas'
# Patched edge ((99589.611, 456667.468) → POINT (99589.61100852319 456671.9422013051)) with height=60.0 from etype='Residential areas'
# Patched edge ((101435.385, 460570.544) → POINT (101434.146 460564.459)) with height=30.0 from etype='Tracks and rural access roads'
# Patched edge ((105056.449, 449464.702) → POINT (105063.60113887078 449466.67463577865)) with height=30.0 from etype='Pedestrian and cycling paths'
# Patched edge ((107298.482, 458373.984) → POINT (107302.2703370812 458379.6309380495)) with height=30.0 from etype='Meadows and open grass'
# Patched edge ((109944.367, 457665.487) → POINT (109944.36710268598 457658.13372336316)) with height=60.0 from etype='Residential areas'
# Patched edge ((103842.394, 451142.367) → POINT (103843.59071178075 451163.1015445732)) with height=30.0 from etype='Regional roads'
# Patched edge ((101174.017, 460846.045) → POINT (101174.01694213985 460842.25387847144)) with height=60.0 from etype='Residential areas'
# Patched edge ((100423.049, 460677.604) → POINT (100453.04728432212 460696.3696488748)) with height=30.0 from etype='Regional roads'
# Patched edge ((103462.931, 450113.221) → POINT (103457.02917123631 450119.12516673893)) with height=30.0 from etype='Tracks and rural access roads'
# Patched edge ((100566.957, 456839.885) → POINT (100574.81087415511 456839.88512986776)) with height=60.0 from etype='Residential areas'
# Patched edge ((100943.174, 460770.544) → POINT (100948.95536359174 460796.54278451885)) with height=30.0 from etype='Forests and woodlands'
#
# Total edges patched: 154
# 0     30.0
# 1     30.0
# 2     30.0
# 3     30.0
# 4     30.0
# 5     30.0
# 6     60.0
# 7     60.0
# 8     60.0
# 9     60.0
# 10    60.0
# 11    60.0
# 12    60.0
# 13    60.0
# 14    30.0
# 15    30.0
# 16    30.0
# 17    30.0
# 18    30.0
# 19    30.0
# 20    30.0
# 21    30.0
# 22    30.0
# 23    60.0
# 24    60.0
# 25    30.0
# 26    30.0
# 27    30.0
# 28    30.0
# 29     NaN
# 30     NaN
# 31    30.0
# Name: Height, dtype: float64

# %%
diagnose_graph(G_final)
# Out:
# GRAPH DIAGNOSTICS
#
# Graph is NOT fully connected. Components: 20268
# Component size distribution: Counter({1: 18590, 4: 451, 6: 186, 2: 129, 3: 61, 8: 59, 9: 56, 10: 44, 7: 40, 5: 39, 12: 35, 11: 33, 18: 22, 15: 21, 22: 20, 21: 19, 14: 16, 32: 15, 13: 15, 17: 15, 16: 14, 27: 14, 19: 12, 26: 12, 29: 12, 33: 12, 31: 11, 24: 11, 40: 11, 41: 11, 25: 11, 35: 10, 28: 10, 37: 9, 23: 9, 44: 9, 30: 9, 20: 8, 48: 8, 38: 8, 56: 7, 47: 7, 36: 7, 49: 7, 34: 7, 66: 7, 39: 6, 53: 6, 43: 6, 45: 6, 52: 5, 54: 4, 42: 4, 74: 4, 58: 4, 64: 4, 82: 4, 70: 4, 67: 4, 51: 3, 115: 3, 63: 3, 57: 3, 46: 3, 69: 3, 145: 2, 87: 2, 116: 2, 85: 2, 114: 2, 72: 2, 81: 2, 112: 2, 122: 2, 204: 2, 61: 2, 59: 2, 100: 2, 55: 2, 88: 2, 50: 2, 91: 2, 65: 2, 299387: 1, 78: 1, 325: 1, 147: 1, 267: 1, 167: 1, 203: 1, 271: 1, 97: 1, 385: 1, 129: 1, 132: 1, 186: 1, 93: 1, 124: 1, 108: 1, 83: 1, 79: 1, 134: 1, 338: 1, 76: 1, 159: 1, 68: 1, 89: 1, 105: 1, 95: 1, 80: 1, 101: 1, 155: 1, 150: 1, 202: 1, 149: 1, 92: 1, 62: 1})
#
# Node types (ntype):
#  - postnl: 81
#  - distribution: 1
#  - line_intersection: 25979
#  - waypoint: 53649
#  - grid_point: 103989
#  - polygon_boundary: 104230
#  - poly_intersection: 60074
#
# Edge types (etype):
#  - postnl_connector: 77
#  - Regional roads: 22761
#  - Pedestrian and cycling paths: 48099
#  - Tracks and rural access roads: 25751
#  - connector: 30209
#  - Residential areas: 38986
#  - Industrial zones: 11075
#  - Cultural sites: 5089
#  - Living and residential streets: 4110
#  - Meadows and open grass: 266031
#  - Motorways and major roads: 2901
#  - Railways: 1612
#  - Rivers, canals and streams: 1993
#  - Retail zones: 1261
#  - Forests and woodlands: 29668
#  - Lakes and ponds: 166
#  - Power lines: 85
#  - Schools and universities: 1134
#  - Wetlands: 948
#  - Agricultural lands: 34049
#  - Commercial zones: 120
#  - Recreational zones: 454
#  - Hospitals: 94
#  - Religious sites: 393
#  - High infrastructures: 6
#  - Communication towers: 5
#  - Power plants: 47
#  - Prisons: 2
#
#  Missing node attributes:
#  - geometry: 0 missing
#  - ntype: 0 missing
#
# Missing edge attributes:
#  - geometry: 0 missing
#  - length: 0 missing
#  - risk: 0 missing
#  - height: 0 missing
#  - etype: 0 missing
#
# Diagnostics complete.

# %%
with open(f"output/{city}.pkl", "wb") as f:
    pickle.dump(G_final, f)

print(f"Graph saved to output/{city}.pkl")
# Out:
# Graph saved to output/alphen-waddinxveen.pkl
